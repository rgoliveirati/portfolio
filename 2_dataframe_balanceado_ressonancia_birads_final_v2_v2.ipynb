# %% [markdown]
# ### IMPORTANDO BIBLIOTECAS

# %%
#Bibliotecas necessárias
import numpy as np
import pandas as pd
import pandas.util.testing as tm
import csv
import seaborn as sns
from datetime import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import unidecode
import unicodedata
from pandas_profiling import ProfileReport
from IPython.display import display, HTML
from IPython.display import display
from matplotlib.pyplot import figure
import string
import altair as alt
# Out:
# C:\Users\Ricardo\AppData\Local\Temp/ipykernel_47164/2783950645.py:4: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
#Importando bases de dados
linha = pd.read_csv('C:/Users/Ricardo/cimatec/tcc/final/linha_ressonancia.csv')

# %%
#Observando dataframe
linha.head()
# Out:
#    Unnamed: 0  registro_paciente codigo_servico  \
# 0       56503              56503       rmmambil
# 1       56504              56504       rmmambil
# 2       56505              56505       rmmambil
# 3       56506              56506       rmmambil
# 4       56507              56507       rmmambil
#
#                                    descricao_servico  data_da_os  \
# 0  RM MAMA                                       ...  2016-12-16
# 1  RM MAMA                                       ...  2016-10-05
# 2  RM MAMA                                       ...  2016-11-10
# 3  RM MAMA                                       ...  2016-06-21
# 4  RM MAMA                                       ...  2016-10-13
#
#                                       texto_do_laudo
# 0   RESSONÂNCIA MAGNÉTICA MAMÁRIA  Indicação clín...
# 1   RESSONÂNCIA MAGNÉTICA MAMÁRIA  Indicação clín...
# 2   RESSONÂNCIA MAGNÉTICA MAMÁRIA  Indicação clín...
# 3  RESSONÂNCIA MAGNÉTICA MAMÁRIA  Indicação clíni...
# 4   RESSONÂNCIA MAGNÉTICA MAMÁRIA  Indicação clín...

# %%
#Excluindo coluna 
linha = linha.drop('Unnamed: 0', 1)
# Out:
# C:\Users\Ricardo\AppData\Local\Temp/ipykernel_47164/191732388.py:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   linha = linha.drop('Unnamed: 0', 1)

# %%
#Observando dataframe
linha.head()
# Out:
#    registro_paciente codigo_servico  \
# 0              56503       rmmambil
# 1              56504       rmmambil
# 2              56505       rmmambil
# 3              56506       rmmambil
# 4              56507       rmmambil
#
#                                    descricao_servico  data_da_os  \
# 0  RM MAMA                                       ...  2016-12-16
# 1  RM MAMA                                       ...  2016-10-05
# 2  RM MAMA                                       ...  2016-11-10
# 3  RM MAMA                                       ...  2016-06-21
# 4  RM MAMA                                       ...  2016-10-13
#
#                                       texto_do_laudo
# 0   RESSONÂNCIA MAGNÉTICA MAMÁRIA  Indicação clín...
# 1   RESSONÂNCIA MAGNÉTICA MAMÁRIA  Indicação clín...
# 2   RESSONÂNCIA MAGNÉTICA MAMÁRIA  Indicação clín...
# 3  RESSONÂNCIA MAGNÉTICA MAMÁRIA  Indicação clíni...
# 4   RESSONÂNCIA MAGNÉTICA MAMÁRIA  Indicação clín...

# %% [markdown]
# ### VERIFICANDO TIPOS DE DADOS E VALORES FALTANTES

# %%
#Dados sobre o dataframe
linha.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8813 entries, 0 to 8812
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   registro_paciente  8813 non-null   int64
#  1   codigo_servico     8813 non-null   object
#  2   descricao_servico  8813 non-null   object
#  3   data_da_os         8813 non-null   object
#  4   texto_do_laudo     8813 non-null   object
# dtypes: int64(1), object(4)
# memory usage: 344.4+ KB
# C:\Users\Ricardo\AppData\Local\Temp/ipykernel_47164/1830142643.py:2: FutureWarning: null_counts is deprecated. Use show_counts instead
#   linha.info(verbose=True, null_counts=True)

# %% [markdown]
# ### TRATANDO COLUNAS ESPECIFICAS EM RELAÇÃO A TIPO DE DADO E APRESENTAÇÕES QUANTO AO ARMAZENAMENTO

# %%
#importando bibliotecas
import re
import nltk
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import chi2
import numpy as np
import string

# %%
#Transformando todas as palavras em lowercase para a variavel texto_do_laudo para dataframe final
linha['texto_do_laudo'] = linha['texto_do_laudo'].str.lower()

#Excluindo acentuação para coluna texto_do_laudo
linha['texto_do_laudo'] = linha['texto_do_laudo'].str.normalize('NFKD').str.encode('ascii', errors='ignore').str.decode('utf-8')

# %%
#Eliminando quebras de linhas para coluna texto_do_laudo
# \'s  \r  \n 
linha['texto_do_laudo'] = linha['texto_do_laudo'].str.replace("\r", " ")
linha['texto_do_laudo'] = linha['texto_do_laudo'].str.replace("\'s", "")
linha['texto_do_laudo'] = linha['texto_do_laudo'].str.replace("\n", " ")
linha['texto_do_laudo'] = linha['texto_do_laudo'].str.replace("    ", " ")

# %%
#Aplicando na base remoção de pontuação
linha['texto_do_laudo'] = [content.translate(str.maketrans('','', string.punctuation)) for content in linha['texto_do_laudo']]

# %%
#Remover espaços excessivos entre palavras para coluna texto_do_laudo
linha.texto_do_laudo = linha.texto_do_laudo.replace('\s+', ' ', regex=True)

# %%
#Baixando as listas de stopwords
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\Ricardo\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#Carregando a lista de stopwords em portugues
stop_words = list(stopwords.words('portuguese'))
stop_words[0:10]
# Out:
# ['de', 'a', 'o', 'que', 'e', 'é', 'do', 'da', 'em', 'um']

# %%
#Aplicando na base

linha['texto_do_laudo_2'] = linha['texto_do_laudo']

for stop_word in stop_words:

    regex_stopword = r"\b" + stop_word + r"\b"
    linha['texto_do_laudo_2'] = linha['texto_do_laudo_2'].str.replace(regex_stopword, '')
# Out:
# C:\Users\Ricardo\AppData\Local\Temp/ipykernel_47164/902855763.py:8: FutureWarning: The default value of regex will change from True to False in a future version.
#   linha['texto_do_laudo_2'] = linha['texto_do_laudo_2'].str.replace(regex_stopword, '')

# %%
#Verificando o antes e o depois
print('Antes: \n'+ linha.loc[1000]['texto_do_laudo'] + '\n \n')

print('Depois: \n'+ linha.loc[1000]['texto_do_laudo_2'])
# Out:
# Antes:
#  ressonancia magnetica mamaria indicacao clinica a paciente realiza o presente estudo para esclarecimento diagnostico dados clinicos e exames anteriores mamografia de 170516 do nosso servico revela microcalcificacoes amorfas em quadrante superolateral qsl da mama esquerda a core biopsy de 150716 teve resultado histopatologico de fibrose estromal com calcificacoes aspectos tecnicos estudo realizado atraves de tecnicas fast spin echo short time inversion recovery stir echo planar imaging epi e 3dgradient echo vibrant com imagens obtidas nos planos sagital e axial ponderadas em t1 e t2 com supressao de gordura alem de sequencia axial com tecnica de difusao apos a infusao venosa do meio de contraste paramagnetico em bolo 150 ml foi realizado estudo dinamico em cinco fases sendo a primeira concluida antes de dois minutos com sequencias sagitais ponderadas em t1 com supressao de gordura tecnica vibrant o posprocessamento do exame foi efetuado em workstation ge com estudo cinetico das lesoes identificadas achados pele e tecido celular subcutaneo tem espessura e sinal preservados exceto por irregularidade focal em quadrante superolateral qsl da mama esquerda complexos areolomamilares estao integros notandose ductos ligeiramente ectasiados e preenchidos por material hiperintenso em t1 hiperproteicohematico mamas apresentam parenquima fibroglandular heterogeneamente distribuido com minimo realce de fundo funcional pelo agente de contraste paramagnetico mama esquerda tem realce linear ao longo do trajeto de agulha em qsl com caracteristicas de resposta inflamatoriareparativa padrao cinetico progressivo sem restricao na sequencia ponderada em difusao pequenos cistos de aprox 06 cm e 03 cm sao identificado em quadrante inferomedial qim da mama direita e quadrante inferolateral qil da mama esquerda respectivamente ausencia de nodulos solidos ou areas de realce nao nodular de aspecto tipicamente suspeito pequenos linfonodos sao observados em cadeias axilares continua continuacao impressao diagnostica alteracoes inflamatoriasreparativas em sitio de biopsia recente em mama esquerda pequeno cisto mamario a direita ductos com conteudo hiperproteicohematico a esquerda birads rm 2
#
#
# Depois:
#  ressonancia magnetica mamaria indicacao clinica  paciente realiza  presente estudo  esclarecimento diagnostico dados clinicos  exames anteriores mamografia  170516   servico revela microcalcificacoes amorfas  quadrante superolateral qsl  mama esquerda  core biopsy  150716  resultado histopatologico  fibrose estromal  calcificacoes aspectos tecnicos estudo realizado atraves  tecnicas fast spin echo short time inversion recovery stir echo planar imaging epi  3dgradient echo vibrant  imagens obtidas  planos sagital  axial ponderadas  t1  t2  supressao  gordura alem  sequencia axial  tecnica  difusao apos  infusao venosa  meio  contraste paramagnetico  bolo 150 ml  realizado estudo dinamico  cinco fases sendo  primeira concluida antes  dois minutos  sequencias sagitais ponderadas  t1  supressao  gordura tecnica vibrant  posprocessamento  exame  efetuado  workstation ge  estudo cinetico  lesoes identificadas achados pele  tecido celular subcutaneo  espessura  sinal preservados exceto  irregularidade focal  quadrante superolateral qsl  mama esquerda complexos areolomamilares estao integros notandose ductos ligeiramente ectasiados  preenchidos  material hiperintenso  t1 hiperproteicohematico mamas apresentam parenquima fibroglandular heterogeneamente distribuido  minimo realce  fundo funcional  agente  contraste paramagnetico mama esquerda  realce linear  longo  trajeto  agulha  qsl  caracteristicas  resposta inflamatoriareparativa padrao cinetico progressivo  restricao  sequencia ponderada  difusao pequenos cistos  aprox 06 cm  03 cm sao identificado  quadrante inferomedial qim  mama direita  quadrante inferolateral qil  mama esquerda respectivamente ausencia  nodulos solidos  areas  realce nao nodular  aspecto tipicamente suspeito pequenos linfonodos sao observados  cadeias axilares continua continuacao impressao diagnostica alteracoes inflamatoriasreparativas  sitio  biopsia recente  mama esquerda pequeno cisto mamario  direita ductos  conteudo hiperproteicohematico  esquerda birads rm 2

# %%
#Removendo numeros
linha['texto_do_laudo_3'] = [content.translate(str.maketrans('','', string.digits)) for content in linha['texto_do_laudo_2']]

# %%
#Verificando o antes e o depois
print('Antes: \n'+ linha.loc[1000]['texto_do_laudo'] + '\n \n')

print('Depois: \n'+ linha.loc[1000]['texto_do_laudo_3'])
# Out:
# Antes:
#  ressonancia magnetica mamaria indicacao clinica a paciente realiza o presente estudo para esclarecimento diagnostico dados clinicos e exames anteriores mamografia de 170516 do nosso servico revela microcalcificacoes amorfas em quadrante superolateral qsl da mama esquerda a core biopsy de 150716 teve resultado histopatologico de fibrose estromal com calcificacoes aspectos tecnicos estudo realizado atraves de tecnicas fast spin echo short time inversion recovery stir echo planar imaging epi e 3dgradient echo vibrant com imagens obtidas nos planos sagital e axial ponderadas em t1 e t2 com supressao de gordura alem de sequencia axial com tecnica de difusao apos a infusao venosa do meio de contraste paramagnetico em bolo 150 ml foi realizado estudo dinamico em cinco fases sendo a primeira concluida antes de dois minutos com sequencias sagitais ponderadas em t1 com supressao de gordura tecnica vibrant o posprocessamento do exame foi efetuado em workstation ge com estudo cinetico das lesoes identificadas achados pele e tecido celular subcutaneo tem espessura e sinal preservados exceto por irregularidade focal em quadrante superolateral qsl da mama esquerda complexos areolomamilares estao integros notandose ductos ligeiramente ectasiados e preenchidos por material hiperintenso em t1 hiperproteicohematico mamas apresentam parenquima fibroglandular heterogeneamente distribuido com minimo realce de fundo funcional pelo agente de contraste paramagnetico mama esquerda tem realce linear ao longo do trajeto de agulha em qsl com caracteristicas de resposta inflamatoriareparativa padrao cinetico progressivo sem restricao na sequencia ponderada em difusao pequenos cistos de aprox 06 cm e 03 cm sao identificado em quadrante inferomedial qim da mama direita e quadrante inferolateral qil da mama esquerda respectivamente ausencia de nodulos solidos ou areas de realce nao nodular de aspecto tipicamente suspeito pequenos linfonodos sao observados em cadeias axilares continua continuacao impressao diagnostica alteracoes inflamatoriasreparativas em sitio de biopsia recente em mama esquerda pequeno cisto mamario a direita ductos com conteudo hiperproteicohematico a esquerda birads rm 2
#
#
# Depois:
#  ressonancia magnetica mamaria indicacao clinica  paciente realiza  presente estudo  esclarecimento diagnostico dados clinicos  exames anteriores mamografia     servico revela microcalcificacoes amorfas  quadrante superolateral qsl  mama esquerda  core biopsy    resultado histopatologico  fibrose estromal  calcificacoes aspectos tecnicos estudo realizado atraves  tecnicas fast spin echo short time inversion recovery stir echo planar imaging epi  dgradient echo vibrant  imagens obtidas  planos sagital  axial ponderadas  t  t  supressao  gordura alem  sequencia axial  tecnica  difusao apos  infusao venosa  meio  contraste paramagnetico  bolo  ml  realizado estudo dinamico  cinco fases sendo  primeira concluida antes  dois minutos  sequencias sagitais ponderadas  t  supressao  gordura tecnica vibrant  posprocessamento  exame  efetuado  workstation ge  estudo cinetico  lesoes identificadas achados pele  tecido celular subcutaneo  espessura  sinal preservados exceto  irregularidade focal  quadrante superolateral qsl  mama esquerda complexos areolomamilares estao integros notandose ductos ligeiramente ectasiados  preenchidos  material hiperintenso  t hiperproteicohematico mamas apresentam parenquima fibroglandular heterogeneamente distribuido  minimo realce  fundo funcional  agente  contraste paramagnetico mama esquerda  realce linear  longo  trajeto  agulha  qsl  caracteristicas  resposta inflamatoriareparativa padrao cinetico progressivo  restricao  sequencia ponderada  difusao pequenos cistos  aprox  cm   cm sao identificado  quadrante inferomedial qim  mama direita  quadrante inferolateral qil  mama esquerda respectivamente ausencia  nodulos solidos  areas  realce nao nodular  aspecto tipicamente suspeito pequenos linfonodos sao observados  cadeias axilares continua continuacao impressao diagnostica alteracoes inflamatoriasreparativas  sitio  biopsia recente  mama esquerda pequeno cisto mamario  direita ductos  conteudo hiperproteicohematico  esquerda birads rm

# %%
#Verificando variáveis
linha.info(verbose=True, null_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8813 entries, 0 to 8812
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   registro_paciente  8813 non-null   int64
#  1   codigo_servico     8813 non-null   object
#  2   descricao_servico  8813 non-null   object
#  3   data_da_os         8813 non-null   object
#  4   texto_do_laudo     8813 non-null   object
#  5   texto_do_laudo_2   8813 non-null   object
#  6   texto_do_laudo_3   8813 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 482.1+ KB
# C:\Users\Ricardo\AppData\Local\Temp/ipykernel_47164/2444266454.py:2: FutureWarning: null_counts is deprecated. Use show_counts instead
#   linha.info(verbose=True, null_counts=True)

# %%
#Observando se ainda há valores nulos
linha.isnull().values.any()
# Out:
# False

# %%
#Dimensoes do dataframe
print('Quantidade de registros e atributos:', linha.shape)
# Out:
# Quantidade de registros e atributos: (8813, 7)

# %%
#Observando dados estatisticos
linha.describe()
# Out:
#        registro_paciente
# count        8813.000000
# mean        61009.761148
# std          2592.516945
# min         56503.000000
# 25%         58753.000000
# 50%         61030.000000
# 75%         63255.000000
# max         65473.000000

# %%
#Renomeando dataframe
ressonancia = linha

# %%
#Datas inicial e final dara a variavel data_da_os
print ("Data da primeira OS:", min(ressonancia['data_da_os']))
print ("Data da última OS:", max(ressonancia['data_da_os']))
# Out:
# Data da primeira OS: 2016-01-04
# Data da última OS: 2021-12-30

# %%
#Verificando dataframe
ressonancia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8813 entries, 0 to 8812
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   registro_paciente  8813 non-null   int64
#  1   codigo_servico     8813 non-null   object
#  2   descricao_servico  8813 non-null   object
#  3   data_da_os         8813 non-null   object
#  4   texto_do_laudo     8813 non-null   object
#  5   texto_do_laudo_2   8813 non-null   object
#  6   texto_do_laudo_3   8813 non-null   object
# dtypes: int64(1), object(6)
# memory usage: 482.1+ KB

# %%
#Estatisticas sobre o dataframe criado
ressonancia.describe()
# Out:
#        registro_paciente
# count        8813.000000
# mean        61009.761148
# std          2592.516945
# min         56503.000000
# 25%         58753.000000
# 50%         61030.000000
# 75%         63255.000000
# max         65473.000000

# %% [markdown]
# ### OBSERVANDO DADOS

# %%
#Contando linhas para variavel codigo_do_servico no dataframe mamotomia
item_counts = ressonancia[["codigo_servico","descricao_servico"]].value_counts()
print('Qtde. laudos por Serviço:')
item_counts.to_frame()
# Out:
# Qtde. laudos por Serviço:
#                                                                       0
# codigo_servico descricao_servico
# rmmambil       RM MAMA                                        ...  7360
# rmmamae        RM MAMA ESQUERDA                               ...   750
# rmmama         RM MAMA DIREITA                                ...   657
# mamabase       RM MAMA PARA MAMOTOMIA E ROLL                  ...    46

# %%
#Contando linhas para variavel codigo_do_servico no dataframe mamotomia
item_counts = ressonancia[["codigo_servico","descricao_servico"]].value_counts(normalize=True).round(4)
print('Qtde. laudos por Serviço:')
(item_counts*100).to_frame()
# Out:
# Qtde. laudos por Serviço:
#                                                                        0
# codigo_servico descricao_servico
# rmmambil       RM MAMA                                        ...  83.51
# rmmamae        RM MAMA ESQUERDA                               ...   8.51
# rmmama         RM MAMA DIREITA                                ...   7.45
# mamabase       RM MAMA PARA MAMOTOMIA E ROLL                  ...   0.52

# %% [markdown]
# ### CRIANDO VARIAVEL AUXILIAR PARA VERIFICAÇÃO DE BI-RADS

# %%
#Criando variavel
ressonancia['birads'] = 'sem categoria'

# %%
#Verificando dataframe
ressonancia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8813 entries, 0 to 8812
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   registro_paciente  8813 non-null   int64
#  1   codigo_servico     8813 non-null   object
#  2   descricao_servico  8813 non-null   object
#  3   data_da_os         8813 non-null   object
#  4   texto_do_laudo     8813 non-null   object
#  5   texto_do_laudo_2   8813 non-null   object
#  6   texto_do_laudo_3   8813 non-null   object
#  7   birads             8813 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 550.9+ KB

# %%
#Associando valores para variavel birads atraves da localização de palavra-chave
ressonancia.loc[ressonancia['texto_do_laudo'].str.contains('rm 0'), 'birads'] = 'categoria 0'
ressonancia.loc[ressonancia['texto_do_laudo'].str.contains('rm 1'), 'birads'] = 'categoria 1'
ressonancia.loc[ressonancia['texto_do_laudo'].str.contains('rm 2'), 'birads'] = 'categoria 2'
ressonancia.loc[ressonancia['texto_do_laudo'].str.contains('rm 3'), 'birads'] = 'categoria 3'
ressonancia.loc[ressonancia['texto_do_laudo'].str.contains('rm 4'), 'birads'] = 'categoria 4'
ressonancia.loc[ressonancia['texto_do_laudo'].str.contains('rm 4a'), 'birads'] = 'categoria 4a'
ressonancia.loc[ressonancia['texto_do_laudo'].str.contains('rm 4 a'), 'birads'] = 'categoria 4a'
ressonancia.loc[ressonancia['texto_do_laudo'].str.contains('rm 4b'), 'birads'] = 'categoria 4b'
ressonancia.loc[ressonancia['texto_do_laudo'].str.contains('rm 4 b'), 'birads'] = 'categoria 4b'
ressonancia.loc[ressonancia['texto_do_laudo'].str.contains('rm 4c'), 'birads'] = 'categoria 4c'
ressonancia.loc[ressonancia['texto_do_laudo'].str.contains('rm 4 c'), 'birads'] = 'categoria 4c'
ressonancia.loc[ressonancia['texto_do_laudo'].str.contains('rm 5'), 'birads'] = 'categoria 5'
ressonancia.loc[ressonancia['texto_do_laudo'].str.contains('rm 6'), 'birads'] = 'categoria 6'

# %%
#Verificando dataframe
ressonancia.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8813 entries, 0 to 8812
# Data columns (total 8 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   registro_paciente  8813 non-null   int64
#  1   codigo_servico     8813 non-null   object
#  2   descricao_servico  8813 non-null   object
#  3   data_da_os         8813 non-null   object
#  4   texto_do_laudo     8813 non-null   object
#  5   texto_do_laudo_2   8813 non-null   object
#  6   texto_do_laudo_3   8813 non-null   object
#  7   birads             8813 non-null   object
# dtypes: int64(1), object(7)
# memory usage: 550.9+ KB

# %%
#Contando ocorrencias para variavel birads
ressonancia.groupby(['birads']).size()
# Out:
# birads
# categoria 0        10
# categoria 1       586
# categoria 2      3387
# categoria 3      1115
# categoria 4       971
# categoria 4a      280
# categoria 4c        9
# categoria 5       352
# categoria 6       723
# sem categoria    1380
# dtype: int64

# %% [markdown]
# ### OBSERVANDO DADOS

# %%
#Contando linhas para variavel birads
item_counts = ressonancia[["birads"]].value_counts()
print('Qtde. de Registros por BiRads:')
item_counts.to_frame()
# Out:
# Qtde. de Registros por BiRads:
#                   0
# birads
# categoria 2    3387
# sem categoria  1380
# categoria 3    1115
# categoria 4     971
# categoria 6     723
# categoria 1     586
# categoria 5     352
# categoria 4a    280
# categoria 0      10
# categoria 4c      9

# %%
#Percentual linhas para variavel birads
item_counts = ressonancia[["birads"]].value_counts(normalize=True)
print('Percentual de Laudos por BiRads:')
(item_counts*100).to_frame()
# Out:
# Percentual de Laudos por BiRads:
#                        0
# birads
# categoria 2    38.431862
# sem categoria  15.658686
# categoria 3    12.651764
# categoria 4    11.017815
# categoria 6     8.203790
# categoria 1     6.649268
# categoria 5     3.994100
# categoria 4a    3.177125
# categoria 0     0.113469
# categoria 4c    0.102122

# %% [markdown]
# ### PREPARANDO DATAFRAME PARA ALGORITMOS DE ARVORES DE DECISAO (BALANCEADO)

# %%
#Criando dataframe com somente texto do laudo e classificação birads
texto_birads = ressonancia[['texto_do_laudo_3', 'birads']]

# %%
#Observando instâncias
texto_birads[:1]
# Out:
#                                     texto_do_laudo_3       birads
# 0   ressonancia magnetica mamaria indicacao clini...  categoria 2

# %%
#Contando valores
texto_birads.birads.value_counts()
# Out:
# categoria 2      3387
# sem categoria    1380
# categoria 3      1115
# categoria 4       971
# categoria 6       723
# categoria 1       586
# categoria 5       352
# categoria 4a      280
# categoria 0        10
# categoria 4c        9
# Name: birads, dtype: int64

# %%
#Criando variavel para mapeamento de categorias
category_codes = {
    'sem categoria': 999,
    'categoria 0': 0,
    'categoria 1': 1,
    'categoria 2': 2,
    'categoria 3': 3,
    'categoria 4': 4,
    'categoria 4a': 41,
    'categoria 4b': 42,
    'categoria 4c': 43,
    'categoria 5': 5,
    'categoria 6': 6
}

# %%
#Mapeamento das categorias
texto_birads['Category_Code'] = texto_birads['birads']
texto_birads = texto_birads.replace({'Category_Code':category_codes})
# Out:
# C:\Users\Ricardo\AppData\Local\Temp/ipykernel_47164/3002229940.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   texto_birads['Category_Code'] = texto_birads['birads']

# %%
#Eliminando categoria
texto_birads = texto_birads[(texto_birads.birads != 'sem categoria')]

# %%
#Contando valores
texto_birads.Category_Code.value_counts()
# Out:
# 2     3387
# 3     1115
# 4      971
# 6      723
# 1      586
# 5      352
# 41     280
# 0       10
# 43       9
# Name: Category_Code, dtype: int64

# %%
#Verificando dataframe
texto_birads.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7433 entries, 0 to 8812
# Data columns (total 3 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   texto_do_laudo_3  7433 non-null   object
#  1   birads            7433 non-null   object
#  2   Category_Code     7433 non-null   int64
# dtypes: int64(1), object(2)
# memory usage: 232.3+ KB

# %% [markdown]
# ### BALANCEANDO DATAFRAME

# %%
#Verificando percentuais de laudos por classes
df2 = pd.DataFrame(texto_birads.groupby('birads').count()['texto_do_laudo_3']).reset_index()

bars = alt.Chart(df2).mark_bar(size=50).encode(
    x=alt.X('birads'),
    y=alt.Y('PercentOfTotal:Q', axis=alt.Axis(format='.0%', title='% de Laudos')),
    color='birads'
).transform_window(
    TotalArticles='sum(texto_do_laudo_3)',
    frame=[None, None]
).transform_calculate(
    PercentOfTotal="datum.texto_do_laudo_3 / datum.TotalArticles"
)

text = bars.mark_text(
    align='center',
    baseline='bottom',
    #dx=5  # Nudges text to right so it doesn't appear on top of the bar
).encode(
    text=alt.Text('PercentOfTotal:Q', format='.1%')
)

(bars + text).interactive().properties(
    height=300, 
    width=700,
    title = "Percentual de laudos para cada categoria",
)
# Out:
# alt.LayerChart(...)

# %%
#Balanceamento de categorias
df_grouped_by = texto_birads.groupby(['Category_Code'])
df_balanced = df_grouped_by.apply(lambda x: x.sample(df_grouped_by.size().max(), replace=True).reset_index(drop=True))
df_balanced = df_balanced.droplevel(['Category_Code'])
df_balanced
# Out:
#                                        texto_do_laudo_3        birads  \
# 0      ressonancia magnetica mamaria indicacao clini...   categoria 0
# 1      ressonancia magnetica mamaria indicacao clini...   categoria 0
# 2      ressonancia magnetica mamaria indicacao clini...   categoria 0
# 3     ressonancia magnetica mamaria indicacao clinic...   categoria 0
# 4      ressonancia magnetica mamaria indicacao clini...   categoria 0
# ...                                                 ...           ...
# 3382   ressonancia magnetica mamaria indicacao clini...  categoria 4c
# 3383  ressonancia magnetica mamaria indicacao clinic...  categoria 4c
# 3384   ressonancia magnetica mamaria indicacao clini...  categoria 4c
# 3385   ressonancia magnetica mamaria indicacao clini...  categoria 4c
# 3386   ressonancia magnetica mamaria indicacao clini...  categoria 4c
#
#       Category_Code
# 0                 0
# 1                 0
# 2                 0
# 3                 0
# 4                 0
# ...             ...
# 3382             43
# 3383             43
# 3384             43
# 3385             43
# 3386             43
#
# [30483 rows x 3 columns]

# %%
#Verificando percentuais de laudos por classes
df2 = pd.DataFrame(df_balanced.groupby('birads').count()['texto_do_laudo_3']).reset_index()

bars = alt.Chart(df2).mark_bar(size=50).encode(
    x=alt.X('birads'),
    y=alt.Y('PercentOfTotal:Q', axis=alt.Axis(format='.0%', title='% de Laudos')),
    color='birads'
).transform_window(
    TotalArticles='sum(texto_do_laudo_3)',
    frame=[None, None]
).transform_calculate(
    PercentOfTotal="datum.texto_do_laudo_3 / datum.TotalArticles"
)

text = bars.mark_text(
    align='center',
    baseline='bottom',
    #dx=5  # Nudges text to right so it doesn't appear on top of the bar
).encode(
    text=alt.Text('PercentOfTotal:Q', format='.1%')
)

(bars + text).interactive().properties(
    height=300, 
    width=700,
    title = "Percentual de laudos para cada categoria após balanceamento",
)
# Out:
# alt.LayerChart(...)

# %%
#Contando valores
df_balanced.groupby(['Category_Code']).size()
# Out:
# Category_Code
# 0     3387
# 1     3387
# 2     3387
# 3     3387
# 4     3387
# 5     3387
# 6     3387
# 41    3387
# 43    3387
# dtype: int64

# %%
#Criando novo dataframe
texto_birads_balanceado = df_balanced[['texto_do_laudo_3','birads']]

# %%
#Exportando para arvore de decisao
texto_birads_balanceado.to_csv('C:/Users/Ricardo/cimatec/tcc/final/texto_birads_balanceado.csv')

# %%
texto_birads_balanceado.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 30483 entries, 0 to 3386
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   texto_do_laudo_3  30483 non-null  object
#  1   birads            30483 non-null  object
# dtypes: object(2)
# memory usage: 714.4+ KB
