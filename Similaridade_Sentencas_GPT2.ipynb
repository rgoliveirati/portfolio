# %% [markdown]
# # **Semantic Textual Similarity**

# %%
#!pip install nltk
#!pip install allennlp
#!pip install pytorch_transformers
#!pip install seaborn
#!pip install simpletransformers
#!pip install pytorch_pretrained_bert

# %%
import scipy
import nltk
nltk.download('punkt')
import tarfile
from nltk.tokenize import word_tokenize
from allennlp import *
import torch
from pytorch_transformers import *
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
from transformers import GPT2Tokenizer, GPT2Model, GPT2LMHeadModel
from transformers import AutoTokenizer 
from transformers import AutoModelForPreTraining  
from transformers import AutoModel 
from simpletransformers.language_representation import RepresentationModel
import numpy as np
from sentence_transformers import SentenceTransformer, util
# Out:
# [nltk_data] Downloading package punkt to /home/jovyan/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %%
tokenizer = GPT2Tokenizer.from_pretrained('gpt2')

# %%
model = GPT2LMHeadModel.from_pretrained('gpt2')

# %%
sentences_1 = 'Uma mulher está dançando na chuva'

# %%
sentences_1
# Out:
# 'Uma mulher está dançando na chuva'

# %%
sentences_2 = 'Uma mulher está dançando na sala'

# %%
sentences_2
# Out:
# 'Uma mulher está dançando na sala'

# %%
sentences_1_split = sentences_1.split()

# %%
sentences_2_split = sentences_2.split()

# %%
sentences1 = sentences_1_split

# %%
sentences1
# Out:
# ['Uma', 'mulher', 'está', 'dançando', 'na', 'chuva']

# %%
sentences2 = sentences_2_split

# %%
sentences2
# Out:
# ['Uma', 'mulher', 'está', 'dançando', 'na', 'sala']

# %%
embeddings1 = torch.Tensor(sentences1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [316], in <cell line: 1>()
# ----> 1 embeddings1 = torch.Tensor(sentences1)
#
# ValueError: too many dimensions 'str'

# %%
embeddings2 = torch.tensor(sentences2)

# %%
embeddings_1
# Out:
# tensor([50256.])

# %%
embeddings_2
# Out:
# tensor([50256.])

# %%
embeddings1 = torch.tensor([tokenizer.convert_tokens_to_ids(embeddings_1)])

# %%
embeddings1
# Out:
# tensor([[50256]])

# %%
cosine_scores = util.cos_sim(embeddings1, embeddings2)

# %%
#Output the pairs with their score
for i in range(len(sentences1)):
    print("{} \t\t {} \t\t Score: {:.4f}".format(sentences1[i], sentences2[i], cosine_scores[i][i]))
# Out:
# Uma mulher está dançando na chuva 		 Uma mulher está dançando na sala 		 Score: 1.0000

# %%
def score(sentence):
    tokenize_input = tokenizer.tokenize(sentence)
    tensor_input = torch.tensor([tokenizer.convert_tokens_to_ids(tokenize_input)])
    loss=model(tensor_input, lm_labels=tensor_input)
    return math.exp(loss)
